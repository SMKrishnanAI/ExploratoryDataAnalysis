# %%
import pandas as pd

# %%
dataset=pd.read_csv("kd.csv")

# %%
dataset.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
dataset.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %% [markdown]
# ## For null values ; action to be taken
# # 1)Replace all null values by central tendency
# # 2)Delete entire row
# # 3)respective to the problem, replace the missing value
# # 4) consider this as a semi supervised model, create a model, so that we can predict the missing value

# %%
import sys
import os
path = os.path.abspath(r'D:\HOPE\AICourseTam\MachineLearning\week5\Univariate\UnivariateAnalysis\3.DataProcessing')
sys.path.append(path)
print(f"Checking path: {path}")
print(f"File exists: {os.path.exists(os.path.join(path, 'univariate.py'))}")

from univariate import univariate
obj=univariate()
quan,qual = obj.quanQual(dataset)
# Out:
# Checking path: D:\HOPE\AICourseTam\MachineLearning\week5\Univariate\UnivariateAnalysis\3.DataProcessing
# File exists: True

# %%
quan
# Out:
# ['id', 'age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo']

# %%
qual
# Out:
# ['rbc',
#  'pc',
#  'pcc',
#  'ba',
#  'pcv',
#  'wc',
#  'rc',
#  'htn',
#  'dm',
#  'cad',
#  'appet',
#  'pe',
#  'ane',
#  'classification']

# %%
dataset[qual].head()
# Out:
#       rbc        pc         pcc          ba pcv    wc   rc  htn   dm cad  \
# 0     NaN    normal  notpresent  notpresent  44  7800  5.2  yes  yes  no
# 1     NaN    normal  notpresent  notpresent  38  6000  NaN   no   no  no
# 2  normal    normal  notpresent  notpresent  31  7500  NaN   no  yes  no
# 3  normal  abnormal     present  notpresent  32  6700  3.9  yes   no  no
# 4  normal    normal  notpresent  notpresent  35  7300  4.6   no   no  no
#
#   appet   pe  ane classification
# 0  good   no   no            ckd
# 1  good   no   no            ckd
# 2  poor   no  yes            ckd
# 3  poor  yes  yes            ckd
# 4  good   no   no            ckd

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.nan, strategy="most_frequent") # Imputer filling null values with Mean(CEntral TEndency)
imp.fit(dataset[qual])
df=imp.transform(dataset[qual])

# %%
dataset[qual].head()
# Out:
#       rbc        pc         pcc          ba pcv    wc   rc  htn   dm cad  \
# 0     NaN    normal  notpresent  notpresent  44  7800  5.2  yes  yes  no
# 1     NaN    normal  notpresent  notpresent  38  6000  NaN   no   no  no
# 2  normal    normal  notpresent  notpresent  31  7500  NaN   no  yes  no
# 3  normal  abnormal     present  notpresent  32  6700  3.9  yes   no  no
# 4  normal    normal  notpresent  notpresent  35  7300  4.6   no   no  no
#
#   appet   pe  ane classification
# 0  good   no   no            ckd
# 1  good   no   no            ckd
# 2  poor   no  yes            ckd
# 3  poor  yes  yes            ckd
# 4  good   no   no            ckd

# %%
dataset[qual].head()
# Out:
#       rbc        pc         pcc          ba pcv    wc   rc  htn   dm cad  \
# 0     NaN    normal  notpresent  notpresent  44  7800  5.2  yes  yes  no
# 1     NaN    normal  notpresent  notpresent  38  6000  NaN   no   no  no
# 2  normal    normal  notpresent  notpresent  31  7500  NaN   no  yes  no
# 3  normal  abnormal     present  notpresent  32  6700  3.9  yes   no  no
# 4  normal    normal  notpresent  notpresent  35  7300  4.6   no   no  no
#
#   appet   pe  ane classification
# 0  good   no   no            ckd
# 1  good   no   no            ckd
# 2  poor   no  yes            ckd
# 3  poor  yes  yes            ckd
# 4  good   no   no            ckd

# %%
df
# Out:
# array([['normal', 'normal', 'notpresent', ..., 'no', 'no', 'ckd'],
#        ['normal', 'normal', 'notpresent', ..., 'no', 'no', 'ckd'],
#        ['normal', 'normal', 'notpresent', ..., 'no', 'yes', 'ckd'],
#        ...,
#        ['normal', 'normal', 'notpresent', ..., 'no', 'no', 'notckd'],
#        ['normal', 'normal', 'notpresent', ..., 'no', 'no', 'notckd'],
#        ['normal', 'normal', 'notpresent', ..., 'no', 'no', 'notckd']],
#       shape=(400, 14), dtype=object)

# %%
df1=pd.DataFrame(df,columns = qual)

# %%
df1
# Out:
#         rbc        pc         pcc          ba pcv    wc   rc  htn   dm cad  \
# 0    normal    normal  notpresent  notpresent  44  7800  5.2  yes  yes  no
# 1    normal    normal  notpresent  notpresent  38  6000  5.2   no   no  no
# 2    normal    normal  notpresent  notpresent  31  7500  5.2   no  yes  no
# 3    normal  abnormal     present  notpresent  32  6700  3.9  yes   no  no
# 4    normal    normal  notpresent  notpresent  35  7300  4.6   no   no  no
# ..      ...       ...         ...         ...  ..   ...  ...  ...  ...  ..
# 395  normal    normal  notpresent  notpresent  47  6700  4.9   no   no  no
# 396  normal    normal  notpresent  notpresent  54  7800  6.2   no   no  no
# 397  normal    normal  notpresent  notpresent  49  6600  5.4   no   no  no
# 398  normal    normal  notpresent  notpresent  51  7200  5.9   no   no  no
# 399  normal    normal  notpresent  notpresent  53  6800  6.1   no   no  no
#
#     appet   pe  ane classification
# ...

# %%
quan
# Out:
# ['id', 'age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo']

# %%
import sys
import os

path = os.path.abspath(r'D:\HOPE\AICourseTam\MachineLearning\week5\Univariate\UnivariateAnalysis\3.DataProcessing')
sys.path.append(path)
print(f"Checking path: {path}")
print(f"File exists: {os.path.exists(os.path.join(path, 'univariate.py'))}")

from univariate import univariate
obj_qu=univariate()
descriptive=obj_qu.univariate(dataset,quan)
# Out:
# Checking path: D:\HOPE\AICourseTam\MachineLearning\week5\Univariate\UnivariateAnalysis\3.DataProcessing
# File exists: True
# D:\HOPE\AICourseTam\MachineLearning\week5\Univariate\UnivariateAnalysis\3.DataProcessing\univariate.py:31: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# ...

# %%
descriptive
# Out:
#                 id        age         bp        sg        al        su  \
# Mean         199.5  51.483376  76.469072  1.017408  1.016949  0.450142
# Median       199.5       55.0       80.0      1.02       0.0       0.0
# Mode             0       60.0       80.0      1.02       0.0       0.0
# Q1:25%       99.75       42.0       70.0      1.01       0.0       0.0
# Q2:50%       199.5       55.0       80.0      1.02       0.0       0.0
# Q3:75%      299.25       64.5       80.0      1.02       2.0       0.0
# 99%         395.01       80.1      110.0     1.025       4.0       4.0
# Q4:100%      399.0       90.0      180.0     1.025       5.0       5.0
# IQR          199.5       22.5       10.0      0.01       2.0       0.0
# 1.5rule     299.25      33.75       15.0     0.015       3.0       0.0
# Lesser      -199.5       8.25       55.0     0.995      -3.0       0.0
# Greater      598.5      98.25       95.0     1.035       5.0       0.0
# ...

# %%
#import numpy as np
#from sklearn.impute import SimpleImputer
imp_qu=SimpleImputer(missing_values=np.nan, strategy="median") # Imputer filling null values with Mean(CEntral TEndency)
imp_qu.fit(dataset[quan])
df_qu=imp_qu.transform(dataset[quan])

# %%
df_qu
# Out:
# array([[  0. ,  48. ,  80. , ..., 138. ,   4.4,  15.4],
#        [  1. ,   7. ,  50. , ..., 138. ,   4.4,  11.3],
#        [  2. ,  62. ,  80. , ..., 138. ,   4.4,   9.6],
#        ...,
#        [397. ,  12. ,  80. , ..., 137. ,   4.4,  15.8],
#        [398. ,  17. ,  60. , ..., 135. ,   4.9,  14.2],
#        [399. ,  58. ,  80. , ..., 141. ,   3.5,  15.8]], shape=(400, 12))

# %%
quan
# Out:
# ['id', 'age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo']

# %%
df_qu1=pd.DataFrame(df_qu,columns = quan)

# %%
df_qu1
# Out:
#         id   age    bp     sg   al   su    bgr    bu   sc    sod  pot  hemo
# 0      0.0  48.0  80.0  1.020  1.0  0.0  121.0  36.0  1.2  138.0  4.4  15.4
# 1      1.0   7.0  50.0  1.020  4.0  0.0  121.0  18.0  0.8  138.0  4.4  11.3
# 2      2.0  62.0  80.0  1.010  2.0  3.0  423.0  53.0  1.8  138.0  4.4   9.6
# 3      3.0  48.0  70.0  1.005  4.0  0.0  117.0  56.0  3.8  111.0  2.5  11.2
# 4      4.0  51.0  80.0  1.010  2.0  0.0  106.0  26.0  1.4  138.0  4.4  11.6
# ..     ...   ...   ...    ...  ...  ...    ...   ...  ...    ...  ...   ...
# 395  395.0  55.0  80.0  1.020  0.0  0.0  140.0  49.0  0.5  150.0  4.9  15.7
# 396  396.0  42.0  70.0  1.025  0.0  0.0   75.0  31.0  1.2  141.0  3.5  16.5
# 397  397.0  12.0  80.0  1.020  0.0  0.0  100.0  26.0  0.6  137.0  4.4  15.8
# 398  398.0  17.0  60.0  1.025  0.0  0.0  114.0  50.0  1.0  135.0  4.9  14.2
# 399  399.0  58.0  80.0  1.025  0.0  0.0  131.0  18.0  1.1  141.0  3.5  15.8
#
# [400 rows x 12 columns]

# %%
imp_qu
# Out:
# SimpleImputer(strategy='median')

# %%
#from univariate import univariate1
#descriptive=univariate1(dataset,quan)

import sys
import os

path = os.path.abspath(r'D:\HOPE\AICourseTam\MachineLearning\week5\Univariate\UnivariateAnalysis\3.DataProcessing')
sys.path.append(path)
print(f"Checking path: {path}")
print(f"File exists: {os.path.exists(os.path.join(path, 'univariate.py'))}")

from univariate import univariate
obj_qu=univariate()
descriptive=obj_qu.univariate(dataset,quan)
# Out:
# Checking path: D:\HOPE\AICourseTam\MachineLearning\week5\Univariate\UnivariateAnalysis\3.DataProcessing
# File exists: True
# D:\HOPE\AICourseTam\MachineLearning\week5\Univariate\UnivariateAnalysis\3.DataProcessing\univariate.py:31: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# ...

# %%
descriptive
# Out:
#                 id        age         bp        sg        al        su  \
# Mean         199.5  51.483376  76.469072  1.017408  1.016949  0.450142
# Median       199.5       55.0       80.0      1.02       0.0       0.0
# Mode             0       60.0       80.0      1.02       0.0       0.0
# Q1:25%       99.75       42.0       70.0      1.01       0.0       0.0
# Q2:50%       199.5       55.0       80.0      1.02       0.0       0.0
# Q3:75%      299.25       64.5       80.0      1.02       2.0       0.0
# 99%         395.01       80.1      110.0     1.025       4.0       4.0
# Q4:100%      399.0       90.0      180.0     1.025       5.0       5.0
# IQR          199.5       22.5       10.0      0.01       2.0       0.0
# 1.5rule     299.25      33.75       15.0     0.015       3.0       0.0
# Lesser      -199.5       8.25       55.0     0.995      -3.0       0.0
# Greater      598.5      98.25       95.0     1.035       5.0       0.0
# ...

# %%
lesser,greater=obj_qu.outlier_col(quan,descriptive)
# Out:
# ['age', 'bp', 'sod', 'hemo']
# ['bp', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot']

# %%
for col_name in lesser:
    dataset[col_name][dataset[col_name] < descriptive[col_name]["Lesser"]] = descriptive[col_name]["Lesser"]

for col_name in greater:
    dataset[col_name][dataset[col_name] > descriptive[col_name]["Greater"]] = descriptive[col_name]["Greater"]

# for col_name in quan:
#     #dataset[col_name][dataset[col_name]=="NaN"]=descriptive[col_name]["Median"]
#     print(f"{col_name}:{np.percentile(dataset[col_name],99)}")
# Out:
# C:\Users\Muthu Krishnan\AppData\Local\Temp\ipykernel_41704\2449550529.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
descriptive
# Out:
#                 id        age         bp        sg        al        su  \
# Mean         199.5  51.483376  76.469072  1.017408  1.016949  0.450142
# Median       199.5       55.0       80.0      1.02       0.0       0.0
# Mode             0       60.0       80.0      1.02       0.0       0.0
# Q1:25%       99.75       42.0       70.0      1.01       0.0       0.0
# Q2:50%       199.5       55.0       80.0      1.02       0.0       0.0
# Q3:75%      299.25       64.5       80.0      1.02       2.0       0.0
# 99%         395.01       80.1      110.0     1.025       4.0       4.0
# Q4:100%      399.0       90.0      180.0     1.025       5.0       5.0
# IQR          199.5       22.5       10.0      0.01       2.0       0.0
# 1.5rule     299.25      33.75       15.0     0.015       3.0       0.0
# Lesser      -199.5       8.25       55.0     0.995      -3.0       0.0
# Greater      598.5      98.25       95.0     1.035       5.0       0.0
# ...
